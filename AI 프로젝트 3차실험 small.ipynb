# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolo11s.pt')

model.train(
    data='/content/drive/MyDrive/프로젝트 4조/Road/dataset/data.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    device=0,
    name='road_damage_v2_small'
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.56 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !cp -r /content/runs/detect/road_damage_v2_small "/content/drive/MyDrive/프로젝트 4조/Road/"

# %% [markdown]
# 검증

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/프로젝트 4조/Road/road_damage_v2_small/weights/best.pt')

results = model.track(source='/content/drive/MyDrive/프로젝트 4조/맑은날.mp4',
                      save=True,
                      conf=0.25,
                      line_width=2,
                      device=0,
                      stream=True)

for r in results:
    pass
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 2 packages in 251ms
# Prepared 1 package in 49ms
# Installed 1 package in 1ms
#  + lap==0.5.13
#
# requirements: AutoUpdate success ✅ 0.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# video 1/1 (frame 1/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 1 Manhole, 78.4ms
# video 1/1 (frame 2/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 1 Manhole, 16.5ms
# ...

# %%
# !cp -r /content/runs/detect/track "/content/drive/MyDrive/프로젝트 4조/최종_영상검증결과/"
