# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/프로젝트 4조/Road/2차실험결과/weights/best.pt')

results = model.predict(source='/content/drive/MyDrive/프로젝트 4조/KakaoTalk_Video_2026-05-25-16-58-43.mp4',
                        save=True,
                        conf=0.25,
                        line_width=2,
                        device=0,
                        stream=True)

for r in results:
    pass
# Out:
# video 1/1 (frame 1/1751) /content/drive/MyDrive/프로젝트 4조/KakaoTalk_Video_2026-05-25-16-58-43.mp4: 384x640 (no detections), 49.4ms
# video 1/1 (frame 2/1751) /content/drive/MyDrive/프로젝트 4조/KakaoTalk_Video_2026-05-25-16-58-43.mp4: 384x640 (no detections), 11.0ms
# video 1/1 (frame 3/1751) /content/drive/MyDrive/프로젝트 4조/KakaoTalk_Video_2026-05-25-16-58-43.mp4: 384x640 (no detections), 14.2ms
# video 1/1 (frame 4/1751) /content/drive/MyDrive/프로젝트 4조/KakaoTalk_Video_2026-05-25-16-58-43.mp4: 384x640 (no detections), 11.7ms
# video 1/1 (frame 5/1751) /content/drive/MyDrive/프로젝트 4조/KakaoTalk_Video_2026-05-25-16-58-43.mp4: 384x640 (no detections), 14.0ms
# video 1/1 (frame 6/1751) /content/drive/MyDrive/프로젝트 4조/KakaoTalk_Video_2026-05-25-16-58-43.mp4: 384x640 (no detections), 12.0ms
# video 1/1 (frame 7/1751) /content/drive/MyDrive/프로젝트 4조/KakaoTalk_Video_2026-05-25-16-58-43.mp4: 384x640 (no detections), 9.7ms
# ...

# %%
# !cp -r /content/runs/detect/predict-3 /content/drive/MyDrive/

# %% [markdown]
# 맑은날 주행 테스트

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/프로젝트 4조/Road/2차실험결과/weights/best.pt')

results = model.track(source='/content/drive/MyDrive/프로젝트 4조/맑은날.mp4',
                      save=True,
                      conf=0.25,
                      classes=[0, 1],
                      line_width=2,
                      device=0,
                      stream=True)

for r in results:
    pass
# Out:
# video 1/1 (frame 1/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 8.2ms
# video 1/1 (frame 2/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 9.7ms
# video 1/1 (frame 3/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 8.8ms
# video 1/1 (frame 4/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 8.0ms
# video 1/1 (frame 5/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 8.7ms
# video 1/1 (frame 6/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 10.5ms
# video 1/1 (frame 7/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 10.8ms
# video 1/1 (frame 8/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 9.1ms
# video 1/1 (frame 9/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 8.0ms
# video 1/1 (frame 10/1442) /content/drive/MyDrive/프로젝트 4조/맑은날.mp4: 480x640 (no detections), 7.8ms
# ...

# %%
# !cp -r /content/runs/detect/* "/content/drive/MyDrive/프로젝트 4조/"
